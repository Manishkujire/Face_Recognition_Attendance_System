# %%
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger
import os
import json
from matplotlib import pyplot as plt

# %%
# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)
test_data_gen = ImageDataGenerator(rescale=1./255)

# Create train generator
train_generator = train_data_gen.flow_from_directory(
    'D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\training',
    target_size=(48, 48),
    batch_size=32,
    color_mode="grayscale",
    class_mode='categorical'
)

# Create validation generator
validation_generator = validation_data_gen.flow_from_directory(
    'D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\validation',
    target_size=(48, 48),
    batch_size=32,
    color_mode="grayscale",
    class_mode='categorical'
)

# Create test generator
test_generator = test_data_gen.flow_from_directory(
    'D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\testing',
    target_size=(48, 48),
    batch_size=32,
    color_mode="grayscale",
    class_mode='categorical'
)
class_indices_array = list(train_generator.class_indices.items())
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from keras.optimizers import Adam
from keras.callbacks import CSVLogger, ModelCheckpoint
from keras.models import Sequential

# Assume you have 41 classes
num_classes = 41

# Create model structure
face_model = Sequential()
face_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
face_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
face_model.add(MaxPooling2D(pool_size=(2, 2)))
face_model.add(Dropout(0.25))

face_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
face_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
face_model.add(MaxPooling2D(pool_size=(2, 2)))
face_model.add(Dropout(0.25))

face_model.add(Flatten())
face_model.add(Dense(512, activation='relu'))
face_model.add(Dropout(0.5))
face_model.add(Dense(num_classes, activation='softmax'))

# Compile the model
face_model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# Define the callbacks
output_dir = "D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\checkpoint"
csv_logger = CSVLogger(os.path.join(output_dir, 'training.log'))

checkpoint_filepath_val = os.path.join(output_dir, 'model_chkpt_val.h5')
model_checkpoint_val = ModelCheckpoint(filepath=checkpoint_filepath_val,
                                       save_weights_only=False,
                                       monitor='val_accuracy',
                                       mode='max',
                                       save_best_only=True,
                                       verbose=1)

checkpoint_filepath_acc = os.path.join(output_dir, 'model_chkpt_acc.h5')
model_checkpoint_acc = ModelCheckpoint(filepath=checkpoint_filepath_acc,
                                       save_weights_only=False,
                                       monitor='accuracy',
                                       mode='max',
                                       save_best_only=True,
                                       verbose=1)

# Train the model
face_model_info = face_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,
    shuffle=True,
    verbose=1,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    callbacks=[csv_logger, model_checkpoint_val, model_checkpoint_acc]
)

# Save model structure in json file
model_json = face_model.to_json()
with open("face_model.json", "w") as json_file:
    json_file.write(model_json)


# Save class indices
labels_json = json.dumps(dict(train_generator.class_indices))
with open("labels_model.json", "w") as json_file:
    json_file.write(labels_json)
    
# Save trained model weights
face_model.save_weights('face_model.h5')
print("done")
# Out:
# Found 328 images belonging to 41 classes.
# Found 41 images belonging to 41 classes.
# Found 41 images belonging to 41 classes.
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 3.7405 - accuracy: 0.0203
# Epoch 1: val_accuracy improved from -inf to 0.03125, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 1: accuracy improved from -inf to 0.02027, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 3s 260ms/step - loss: 3.7405 - accuracy: 0.0203 - val_loss: 3.7061 - val_accuracy: 0.0312
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 3.7046 - accuracy: 0.0270
# Epoch 2: val_accuracy did not improve from 0.03125
#
# Epoch 2: accuracy improved from 0.02027 to 0.02703, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 152ms/step - loss: 3.7046 - accuracy: 0.0270 - val_loss: 3.7067 - val_accuracy: 0.0312
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 3.7050 - accuracy: 0.0439
# Epoch 3: val_accuracy improved from 0.03125 to 0.06250, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 3: accuracy improved from 0.02703 to 0.04392, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 160ms/step - loss: 3.7050 - accuracy: 0.0439 - val_loss: 3.7045 - val_accuracy: 0.0625
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 3.7034 - accuracy: 0.0135
# Epoch 4: val_accuracy did not improve from 0.06250
#
# Epoch 4: accuracy did not improve from 0.04392
# 10/10 [==============================] - 1s 144ms/step - loss: 3.7034 - accuracy: 0.0135 - val_loss: 3.6957 - val_accuracy: 0.0312
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 3.6929 - accuracy: 0.0372
# Epoch 5: val_accuracy did not improve from 0.06250
#
# Epoch 5: accuracy did not improve from 0.04392
# 10/10 [==============================] - 2s 164ms/step - loss: 3.6929 - accuracy: 0.0372 - val_loss: 3.6997 - val_accuracy: 0.0625
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 3.6841 - accuracy: 0.0439
# Epoch 6: val_accuracy did not improve from 0.06250
#
# Epoch 6: accuracy did not improve from 0.04392
# 10/10 [==============================] - 2s 159ms/step - loss: 3.6841 - accuracy: 0.0439 - val_loss: 3.6836 - val_accuracy: 0.0312
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 3.6881 - accuracy: 0.0372
# Epoch 7: val_accuracy improved from 0.06250 to 0.09375, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 7: accuracy did not improve from 0.04392
# 10/10 [==============================] - 2s 189ms/step - loss: 3.6881 - accuracy: 0.0372 - val_loss: 3.6641 - val_accuracy: 0.0938
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 3.6612 - accuracy: 0.0709
# Epoch 8: val_accuracy did not improve from 0.09375
#
# Epoch 8: accuracy improved from 0.04392 to 0.07095, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 185ms/step - loss: 3.6612 - accuracy: 0.0709 - val_loss: 3.6568 - val_accuracy: 0.0625
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 3.6467 - accuracy: 0.0608
# Epoch 9: val_accuracy did not improve from 0.09375
#
# Epoch 9: accuracy did not improve from 0.07095
# 10/10 [==============================] - 2s 192ms/step - loss: 3.6467 - accuracy: 0.0608 - val_loss: 3.6214 - val_accuracy: 0.0625
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 3.6072 - accuracy: 0.0642
# Epoch 10: val_accuracy improved from 0.09375 to 0.12500, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 10: accuracy did not improve from 0.07095
# 10/10 [==============================] - 3s 288ms/step - loss: 3.6072 - accuracy: 0.0642 - val_loss: 3.5361 - val_accuracy: 0.1250
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 3.5781 - accuracy: 0.0980
# Epoch 11: val_accuracy improved from 0.12500 to 0.21875, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 11: accuracy improved from 0.07095 to 0.09797, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 393ms/step - loss: 3.5781 - accuracy: 0.0980 - val_loss: 3.5264 - val_accuracy: 0.2188
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 3.4909 - accuracy: 0.0777
# Epoch 12: val_accuracy improved from 0.21875 to 0.28125, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 12: accuracy did not improve from 0.09797
# 10/10 [==============================] - 4s 373ms/step - loss: 3.4909 - accuracy: 0.0777 - val_loss: 3.3743 - val_accuracy: 0.2812
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 3.4106 - accuracy: 0.1014
# Epoch 13: val_accuracy did not improve from 0.28125
#
# Epoch 13: accuracy improved from 0.09797 to 0.10135, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 374ms/step - loss: 3.4106 - accuracy: 0.1014 - val_loss: 3.3202 - val_accuracy: 0.2812
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 3.2535 - accuracy: 0.1622
# Epoch 14: val_accuracy improved from 0.28125 to 0.31250, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 14: accuracy improved from 0.10135 to 0.16216, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 379ms/step - loss: 3.2535 - accuracy: 0.1622 - val_loss: 3.0158 - val_accuracy: 0.3125
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 3.0649 - accuracy: 0.1723
# Epoch 15: val_accuracy improved from 0.31250 to 0.43750, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 15: accuracy improved from 0.16216 to 0.17230, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 385ms/step - loss: 3.0649 - accuracy: 0.1723 - val_loss: 2.8599 - val_accuracy: 0.4375
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 2.8703 - accuracy: 0.2162
# Epoch 16: val_accuracy improved from 0.43750 to 0.53125, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 16: accuracy improved from 0.17230 to 0.21622, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 382ms/step - loss: 2.8703 - accuracy: 0.2162 - val_loss: 2.5345 - val_accuracy: 0.5312
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 2.7446 - accuracy: 0.2905
# Epoch 17: val_accuracy improved from 0.53125 to 0.56250, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 17: accuracy improved from 0.21622 to 0.29054, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 392ms/step - loss: 2.7446 - accuracy: 0.2905 - val_loss: 2.3445 - val_accuracy: 0.5625
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 2.4176 - accuracy: 0.3243
# Epoch 18: val_accuracy improved from 0.56250 to 0.62500, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
# Epoch 18: accuracy improved from 0.29054 to 0.32432, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 380ms/step - loss: 2.4176 - accuracy: 0.3243 - val_loss: 2.1149 - val_accuracy: 0.6250
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 2.1756 - accuracy: 0.3615
# Epoch 19: val_accuracy improved from 0.62500 to 0.78125, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 19: accuracy improved from 0.32432 to 0.36149, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 385ms/step - loss: 2.1756 - accuracy: 0.3615 - val_loss: 1.6427 - val_accuracy: 0.7812
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 1.8695 - accuracy: 0.4595
# Epoch 20: val_accuracy did not improve from 0.78125
#
# Epoch 20: accuracy improved from 0.36149 to 0.45946, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 363ms/step - loss: 1.8695 - accuracy: 0.4595 - val_loss: 1.5775 - val_accuracy: 0.6562
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 1.6972 - accuracy: 0.4865
# Epoch 21: val_accuracy did not improve from 0.78125
#
# Epoch 21: accuracy improved from 0.45946 to 0.48649, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 367ms/step - loss: 1.6972 - accuracy: 0.4865 - val_loss: 1.2592 - val_accuracy: 0.7188
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 1.5521 - accuracy: 0.5338
# Epoch 22: val_accuracy did not improve from 0.78125
#
# Epoch 22: accuracy improved from 0.48649 to 0.53378, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 386ms/step - loss: 1.5521 - accuracy: 0.5338 - val_loss: 1.1246 - val_accuracy: 0.7812
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 1.3716 - accuracy: 0.5980
# Epoch 23: val_accuracy improved from 0.78125 to 0.81250, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 23: accuracy improved from 0.53378 to 0.59797, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 386ms/step - loss: 1.3716 - accuracy: 0.5980 - val_loss: 0.9014 - val_accuracy: 0.8125
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 1.1176 - accuracy: 0.6419
# Epoch 24: val_accuracy improved from 0.81250 to 0.87500, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 24: accuracy improved from 0.59797 to 0.64189, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 4s 388ms/step - loss: 1.1176 - accuracy: 0.6419 - val_loss: 0.6345 - val_accuracy: 0.8750
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 0.9808 - accuracy: 0.6993
# Epoch 25: val_accuracy did not improve from 0.87500
#
# Epoch 25: accuracy improved from 0.64189 to 0.69932, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 3s 273ms/step - loss: 0.9808 - accuracy: 0.6993 - val_loss: 0.7227 - val_accuracy: 0.8125
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 0.9154 - accuracy: 0.7031
# Epoch 26: val_accuracy improved from 0.87500 to 0.90625, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 26: accuracy improved from 0.69932 to 0.70312, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 212ms/step - loss: 0.9154 - accuracy: 0.7031 - val_loss: 0.4856 - val_accuracy: 0.9062
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 0.8152 - accuracy: 0.7669
# Epoch 27: val_accuracy did not improve from 0.90625
#
# Epoch 27: accuracy improved from 0.70312 to 0.76689, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 194ms/step - loss: 0.8152 - accuracy: 0.7669 - val_loss: 0.5287 - val_accuracy: 0.8750
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 0.6980 - accuracy: 0.8108
# Epoch 28: val_accuracy improved from 0.90625 to 0.93750, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 28: accuracy improved from 0.76689 to 0.81081, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 216ms/step - loss: 0.6980 - accuracy: 0.8108 - val_loss: 0.4031 - val_accuracy: 0.9375
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5327 - accuracy: 0.8615
# Epoch 29: val_accuracy did not improve from 0.93750
#
# Epoch 29: accuracy improved from 0.81081 to 0.86149, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 203ms/step - loss: 0.5327 - accuracy: 0.8615 - val_loss: 0.5258 - val_accuracy: 0.8125
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5459 - accuracy: 0.8378
# Epoch 30: val_accuracy did not improve from 0.93750
#
# Epoch 30: accuracy did not improve from 0.86149
# 10/10 [==============================] - 2s 190ms/step - loss: 0.5459 - accuracy: 0.8378 - val_loss: 0.3721 - val_accuracy: 0.9062
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.8682
# Epoch 31: val_accuracy did not improve from 0.93750
#
# Epoch 31: accuracy improved from 0.86149 to 0.86824, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 213ms/step - loss: 0.4668 - accuracy: 0.8682 - val_loss: 0.2804 - val_accuracy: 0.9375
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.8919
# Epoch 32: val_accuracy did not improve from 0.93750
#
# Epoch 32: accuracy improved from 0.86824 to 0.89189, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 179ms/step - loss: 0.3942 - accuracy: 0.8919 - val_loss: 0.2968 - val_accuracy: 0.9062
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4203 - accuracy: 0.8716
# Epoch 33: val_accuracy improved from 0.93750 to 1.00000, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_val.h5
#
# Epoch 33: accuracy did not improve from 0.89189
# 10/10 [==============================] - 2s 166ms/step - loss: 0.4203 - accuracy: 0.8716 - val_loss: 0.1298 - val_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3809 - accuracy: 0.8716
# Epoch 34: val_accuracy did not improve from 1.00000
#
# Epoch 34: accuracy did not improve from 0.89189
# 10/10 [==============================] - 2s 164ms/step - loss: 0.3809 - accuracy: 0.8716 - val_loss: 0.2619 - val_accuracy: 0.9688
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3844 - accuracy: 0.8986
# Epoch 35: val_accuracy did not improve from 1.00000
#
# Epoch 35: accuracy improved from 0.89189 to 0.89865, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 164ms/step - loss: 0.3844 - accuracy: 0.8986 - val_loss: 0.3615 - val_accuracy: 0.8750
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3201 - accuracy: 0.9020
# Epoch 36: val_accuracy did not improve from 1.00000
#
# Epoch 36: accuracy improved from 0.89865 to 0.90203, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 167ms/step - loss: 0.3201 - accuracy: 0.9020 - val_loss: 0.1846 - val_accuracy: 0.9062
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.8986
# Epoch 37: val_accuracy did not improve from 1.00000
#
# Epoch 37: accuracy did not improve from 0.90203
# 10/10 [==============================] - 2s 169ms/step - loss: 0.2864 - accuracy: 0.8986 - val_loss: 0.1838 - val_accuracy: 0.9375
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9088
# Epoch 38: val_accuracy did not improve from 1.00000
#
# Epoch 38: accuracy improved from 0.90203 to 0.90878, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 176ms/step - loss: 0.2767 - accuracy: 0.9088 - val_loss: 0.1456 - val_accuracy: 0.9688
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.8953
# Epoch 39: val_accuracy did not improve from 1.00000
#
# Epoch 39: accuracy did not improve from 0.90878
# 10/10 [==============================] - 2s 162ms/step - loss: 0.2629 - accuracy: 0.8953 - val_loss: 0.1579 - val_accuracy: 0.9375
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9324
# Epoch 40: val_accuracy did not improve from 1.00000
#
# Epoch 40: accuracy improved from 0.90878 to 0.93243, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 161ms/step - loss: 0.2220 - accuracy: 0.9324 - val_loss: 0.1841 - val_accuracy: 0.9375
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9291
# Epoch 41: val_accuracy did not improve from 1.00000
#
# Epoch 41: accuracy did not improve from 0.93243
# 10/10 [==============================] - 2s 156ms/step - loss: 0.2066 - accuracy: 0.9291 - val_loss: 0.2660 - val_accuracy: 0.9062
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9155
# Epoch 42: val_accuracy did not improve from 1.00000
#
# Epoch 42: accuracy did not improve from 0.93243
# 10/10 [==============================] - 2s 181ms/step - loss: 0.2681 - accuracy: 0.9155 - val_loss: 0.2369 - val_accuracy: 0.9375
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9257
# Epoch 43: val_accuracy did not improve from 1.00000
#
# Epoch 43: accuracy did not improve from 0.93243
# 10/10 [==============================] - 2s 163ms/step - loss: 0.2343 - accuracy: 0.9257 - val_loss: 0.2008 - val_accuracy: 0.9062
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9493
# Epoch 44: val_accuracy did not improve from 1.00000
#
# Epoch 44: accuracy improved from 0.93243 to 0.94932, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 165ms/step - loss: 0.1930 - accuracy: 0.9493 - val_loss: 0.1260 - val_accuracy: 0.9688
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9595
# Epoch 45: val_accuracy did not improve from 1.00000
#
# Epoch 45: accuracy improved from 0.94932 to 0.95946, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 162ms/step - loss: 0.1525 - accuracy: 0.9595 - val_loss: 0.1899 - val_accuracy: 0.9375
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9527
# Epoch 46: val_accuracy did not improve from 1.00000
#
# Epoch 46: accuracy did not improve from 0.95946
# 10/10 [==============================] - 2s 160ms/step - loss: 0.1499 - accuracy: 0.9527 - val_loss: 0.0940 - val_accuracy: 0.9688
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9628
# Epoch 47: val_accuracy did not improve from 1.00000
#
# Epoch 47: accuracy improved from 0.95946 to 0.96284, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 160ms/step - loss: 0.1473 - accuracy: 0.9628 - val_loss: 0.1590 - val_accuracy: 0.9688
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9527
# Epoch 48: val_accuracy did not improve from 1.00000
#
# Epoch 48: accuracy did not improve from 0.96284
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1540 - accuracy: 0.9527 - val_loss: 0.1808 - val_accuracy: 0.9688
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.9426
# Epoch 49: val_accuracy did not improve from 1.00000
#
# Epoch 49: accuracy did not improve from 0.96284
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1769 - accuracy: 0.9426 - val_loss: 0.1865 - val_accuracy: 0.9062
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9662
# Epoch 50: val_accuracy did not improve from 1.00000
#
# Epoch 50: accuracy improved from 0.96284 to 0.96622, saving model to D:\Downloads\Face-Recognition-master (1)\Face-Recognition-master\checkpoint\model_chkpt_acc.h5
# 10/10 [==============================] - 2s 165ms/step - loss: 0.1165 - accuracy: 0.9662 - val_loss: 0.1043 - val_accuracy: 0.9688
# done

# %%
# ... (previous code)
import numpy as np

test_generator = test_data_gen.flow_from_directory(
    'D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\Testing',
    target_size=(48, 48),
    batch_size=64,
    color_mode="grayscale",
    class_mode='categorical'
)

def test_accuracy(test_generator, face_model):
    try:
        # Use the generator to load the test dataset
        test_images, test_labels = test_generator.next()

#         test_images = test_images.astype('float32') / 255.0
#         print(test_generator[0][0][6])
# #         Use the trained model to predict labels for the test set
#         with open("face_model.json", "r") as json_file:
#             loaded_model_json = json_file.read()
#             face_model = model_from_json(loaded_model_json)

#         face_model.load_weights('D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\checkpoint\\model_chkpt_acc.h5')
        
        predictions = face_model.predict(test_images)
#         print(predictions)
        # Convert predictions to class labels
        predicted_labels = np.argmax(predictions, axis=1)
        print(predicted_labels)
        # Compare predicted labels with true labels
        true_labels = np.argmax(test_labels, axis=1)
        print(true_labels)

        # Calculate accuracy
        accuracy = np.mean(predicted_labels == true_labels)
#         print(test_labels)

        return accuracy

    except Exception as e:
        print(f'Error: {str(e)}')
        return None

# Calculate and print test accuracy
test_accuracy_value= test_accuracy(test_generator, face_model)

if test_accuracy_value is not None:
    print(f'Test Accuracy: {test_accuracy_value * 100:.2f}%')
else:
    print('Error calculating test accuracy.')
# Out:
# Found 41 images belonging to 41 classes.
# 2/2 [==============================] - 0s 15ms/step
# [29 13 31 10 23 12  6 35 16 31 14  3 34 34  0 18 40 22 39 20  4 33 26 38
#  36  8 27  5 29 17  9 11 30 32 37 21  2 25  7 19 24]
# [29 13 15 10 23 12  6 35 16 31 14  3 28 34  0 18 40 22 39 20  4 33 26 38
#  36  8 27  5  1 17  9 11 30 32 37 21  2 25  7 19 24]
# Test Accuracy: 92.68%

# %%
import cv2
import numpy as np
from keras.models import model_from_json
from keras.preprocessing import image
class_indices_array={}
with open("D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\labels_model.json", "r") as json_file:
    class_indices_array = json.load(json_file)    

# Load the model structure from the saved json file
with open("D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\face_model.json", "r") as json_file:
    loaded_model_json = json_file.read()
    face_model = model_from_json(loaded_model_json)

# Load the trained weights into the model
# face_model.load_weights('D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\checkpoint\\model_chkpt_acc.h5')
face_model.load_weights('face_model.h5')

# Load the image for detection
img_path = r"D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\testing\\s14\\132_14.jpg"
# img_path = r"D:\\Downloads\\larine.jpg"
img = image.load_img(img_path, target_size=(48, 48), color_mode="grayscale")
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

# Make prediction
face_prediction = face_model.predict(img_array)
print(face_prediction)
# print(emotion_prediction[0][23]*100)

# Get the predicted emotion label
predicted_label_index = np.argmax(face_prediction)
predicted_label = class_indices_array[predicted_label_index][0]
# accuracy_value = float(face_prediction[0][predicted_label_index] * 100)
print(class_indices_array)
print(predicted_label)

# Display the image with the predicted label
img = cv2.imread(img_path)
cv2.putText(img, f"Predicted: {predicted_label}", (1, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Extract the numerical value of accuracy
print(f"Prediction Accuracy: {accuracy_value:.2f}%")

cv2.imshow('Image Detection', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 from keras.preprocessing import image
#       5 class_indices_array={}
# ----> 6 with open("D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\labels_model.json", "r") as json_file:
#       7     class_indices_array = json.load(json_file)
#       9 # Load the model structure from the saved json file
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\labels_model.json'

# %%
true_labels
# Out:
# array([ 4, 21,  1, 32,  0,  3, 23, 18, 11, 27, 22,  9, 10, 29, 34, 12,  3,
#         6, 29, 30, 24, 15,  2,  5, 17, 28, 30, 22, 13,  0,  2,  1],
#       dtype=int64)

# %%
import cv2
import numpy as np
from keras.models import model_from_json
from keras.preprocessing import image

# Load the model structure from the saved json file
with open("face_model.json", "r") as json_file:
    loaded_model_json = json_file.read()
    face_model = model_from_json(loaded_model_json)

# Load the trained weights into the model
face_model.load_weights('D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\checkpoint\\model_chkpt_acc.h5')
# face_model.load_weights('face_model.h5')

# Load the image for detection
img_path = r"D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\Testing\\s18\\174_18.jpg"
# img_path = r"D:\\Downloads\\larine.jpg"
img = image.load_img(img_path, target_size=(48, 48), color_mode="grayscale")
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

# Make prediction
face_prediction = face_model.predict(test_generator[0][0])
predicted_labels = np.argmax(face_prediction, axis=1)
print(test_labels)

# Compare predicted labels with true labels
true_labels = np.argmax(test_labels, axis=1)
# predicted_label_i[0][0]ndex = np.argmax(face_prediction)
# predicted_label = class_indices_array[predicted_label_index][0]
# accuracy_value = float(face_prediction[0][predicted_label_index] * 100)
# print(class_indices_array)
print(face_prediction)

original_shape = (80, 70)

# Create a graph to visualize the predictions
fig, axes = plt.subplots(6, 4, figsize=(10, 8))

for i, ax in enumerate(axes.flatten()):
    # Reshape the flattened image to its original shape
    ax.imshow(test_generator[0][0][i].reshape(original_shape), cmap='gray')
    ax.set_title(f'Actual: {test_generator[0][1][i]}\nPredicted: {test_generator[0][0][predicted_label_index]}')
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 18
#      16 img_path = r"D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\Testing\\s18\\174_18.jpg"
#      17 # img_path = r"D:\\Downloads\\larine.jpg"
# ---> 18 img = image.load_img(img_path, target_size=(48, 48), color_mode="grayscale")
#      19 img_array = image.img_to_array(img)
#      20 img_array = np.expand_dims(img_array, axis=0)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\\\Downloads\\\\Face-Recognition-master (1)\\\\Face-Recognition-master\\\\Datasets\\\\Faces\\\\Testing\\\\s18\\\\174_18.jpg'

# %%
labels_json = json.dumps(train_generator.class_indices)
with open("labels_model.json", "w") as json_file:
    json_file.write(labels_json)

# %%
import os
import json
import numpy as np
import cv2
from keras.models import model_from_json
from keras.preprocessing import image
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Load the model structure from the saved json file
with open("face_model.json", "r") as json_file:
    loaded_model_json = json_file.read()
    face_model = model_from_json(loaded_model_json)

# Load the trained weights into the model
face_model.load_weights('face_model.h5')
# face_model.load_weights('D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\checkpoint\\model_chkpt_val.h5')
# Load the class indices
with open("labels_model.json", "r") as json_file:
    class_indices = json.load(json_file)

# Load the test generator for making predictions
test_generator = test_data_gen.flow_from_directory(
    'D:\\Downloads\\Face-Recognition-master (1)\\Face-Recognition-master\\Datasets\\Faces\\testing',
    target_size=(48, 48),
    batch_size=32,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=False  # Ensure the order of predictions matches the order of images
)

# Make predictions on the test set
predictions = face_model.predict(test_generator)

# Get the predicted labels and true labels
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_generator.classes

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# # Display the confusion matrix
# conf_matrix = confusion_matrix(true_labels, predicted_labels)
# print("Confusion Matrix:")
# print(conf_matrix)

# Display classification report
class_report = classification_report(true_labels, predicted_labels, target_names=class_indices.keys())
print("Classification Report:")
print(class_report)

# Visualization of predictions
original_shape = (48, 48)

# Create a graph to visualize the predictions
fig, axes = plt.subplots(6, 4, figsize=(10, 8))

for i, ax in enumerate(axes.flatten()):
    # Load the image for display
    img_path = os.path.join(test_generator.directory, test_generator.filenames[i])
    img = image.load_img(img_path, target_size=(48, 48), color_mode="grayscale")
    img_array = image.img_to_array(img)
    img_array /= 255.0

    # Reshape the flattened image to its original shape
    ax.imshow(img_array.reshape(original_shape), cmap='gray')

    # Get the predicted label
    predicted_label_index = np.argmax(predictions[i])
    predicted_label = list(class_indices.keys())[predicted_label_index]

    # Get the true label
    true_label = test_generator.classes[i]
    
    # Display the true and predicted labels with accuracy
    ax.set_title(f'True: {list(class_indices.keys())[true_label]}\nPredicted: {predicted_label}\nAccuracy: {predictions[i][predicted_label_index]:.2f}')
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 41 images belonging to 41 classes.
# WARNING:tensorflow:6 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FD0732A840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 17ms/step
# Test Accuracy: 100.00%
# Classification Report:
#               precision    recall  f1-score   support
#
#           s1       1.00      1.00      1.00         1
#          s10       1.00      1.00      1.00         1
#          s11       1.00      1.00      1.00         1
#          s12       1.00      1.00      1.00         1
#          s13       1.00      1.00      1.00         1
#          s14       1.00      1.00      1.00         1
#          s15       1.00      1.00      1.00         1
#          s16       1.00      1.00      1.00         1
#          s17       1.00      1.00      1.00         1
#          s18       1.00      1.00      1.00         1
#          s19       1.00      1.00      1.00         1
#           s2       1.00      1.00      1.00         1
#          s20       1.00      1.00      1.00         1
#          s21       1.00      1.00      1.00         1
#          s22       1.00      1.00      1.00         1
#          s23       1.00      1.00      1.00         1
#          s24       1.00      1.00      1.00         1
#          s25       1.00      1.00      1.00         1
#          s26       1.00      1.00      1.00         1
#          s27       1.00      1.00      1.00         1
#          s28       1.00      1.00      1.00         1
#          s29       1.00      1.00      1.00         1
#           s3       1.00      1.00      1.00         1
#          s30       1.00      1.00      1.00         1
#          s31       1.00      1.00      1.00         1
#          s32       1.00      1.00      1.00         1
#          s33       1.00      1.00      1.00         1
#          s34       1.00      1.00      1.00         1
#          s35       1.00      1.00      1.00         1
#          s36       1.00      1.00      1.00         1
#          s37       1.00      1.00      1.00         1
#          s38       1.00      1.00      1.00         1
#          s39       1.00      1.00      1.00         1
#           s4       1.00      1.00      1.00         1
#          s40       1.00      1.00      1.00         1
#          s41       1.00      1.00      1.00         1
#           s5       1.00      1.00      1.00         1
#           s6       1.00      1.00      1.00         1
#           s7       1.00      1.00      1.00         1
#           s8       1.00      1.00      1.00         1
#           s9       1.00      1.00      1.00         1
#
#     accuracy                           1.00        41
#    macro avg       1.00      1.00      1.00        41
# weighted avg       1.00      1.00      1.00        41
